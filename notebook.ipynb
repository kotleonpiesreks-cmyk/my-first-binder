# %%
import pandas as pd
import numpy as np

produkty = ['telefon', 'komputer', 'tablet', 'sluchawki', 'tv', 'glosnik']
sprzedaz = np.random.randint(10, 100, size=len(produkty))
ceny = [2500, 4500, 1200, 350, 900, 450]

df = pd.DataFrame({
    'PRODUKTY': produkty, 
    'SPRZEDAZ': sprzedaz, 
    'CENY': ceny
})

df
